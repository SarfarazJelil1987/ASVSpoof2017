# %% [markdown]
# ## Title: Extracting spectrogram of ASVSpoof 2017 data
#
# In this notebook, spectrogams for train, development and evaluation sets of ASVSpoof 2017 are extracted. The wavefiles are read one by one using the protocol files. The spectrograms are then saved to respective folders.

# %% [markdown]
# ## Spectrograms for the train data

# %%
! python3 extract_spectrogram.py -pf /home/sarfaraz/sarfaraz/phd_work/data/DS_10283_3055/protocol_V2/ASVspoof2017_V2_train.trn.txt -t train  -w /home/sarfaraz/sarfaraz/phd_work/data/DS_10283_3055/ASVspoof2017_V2_train -o /home/sarfaraz/sarfaraz/phd_work/spectrograms
# Out:
#   1%|▌                                        | 40/3014 [00:07<09:28,  5.23it/s]extract_spectrogram.py:57: RuntimeWarning: divide by zero encountered in log
#   plt.pcolormesh(time, freq, np.log(spec),cmap=cmap)
# 100%|███████████████████████████████████████| 3014/3014 [09:22<00:00,  5.36it/s]

# %% [markdown]
# ## Spectrograms for the validation data

# %%
! python3 extract_spectrogram.py -pf /home/sarfaraz/sarfaraz/phd_work/data/DS_10283_3055/protocol_V2/ASVspoof2017_V2_dev.trl.txt -t development  -w /home/sarfaraz/sarfaraz/phd_work/data/DS_10283_3055/ASVspoof2017_V2_dev -o /home/sarfaraz/sarfaraz/phd_work/spectrograms
# Out:
# Destination already exists
# Destination already exists
#  20%|███████▉                                | 339/1710 [01:11<05:02,  4.53it/s]extract_spectrogram.py:57: RuntimeWarning: divide by zero encountered in log
#   plt.pcolormesh(time, freq, np.log(spec),cmap=cmap)
# 100%|███████████████████████████████████████| 1710/1710 [05:51<00:00,  4.87it/s]

# %% [markdown]
# ## Spectrograms for the evaluation data

# %%
! python3 extract_spectrogram.py -pf /home/sarfaraz/sarfaraz/phd_work/data/DS_10283_3055/protocol_V2/ASVspoof2017_V2_eval.trl.txt -t evaluation  -w /home/sarfaraz/sarfaraz/phd_work/data/DS_10283_3055/ASVspoof2017_V2_eval -o /home/sarfaraz/sarfaraz/phd_work/spectrograms
# Out:
#   1%|▌                                      | 173/13306 [00:39<48:30,  4.51it/s]extract_spectrogram.py:57: RuntimeWarning: divide by zero encountered in log
#   plt.pcolormesh(time, freq, np.log(spec),cmap=cmap)
# 100%|█████████████████████████████████████| 13306/13306 [50:05<00:00,  4.43it/s]

# %% [markdown]
# ## Example of genuine spectrogram

# %%
from IPython.display import Image
Image('images/T_1000001.png')

# %% [markdown]
# ## Example of spoof spectrogram

# %%
from IPython.display import Image
Image('images/T_1001509.png')
